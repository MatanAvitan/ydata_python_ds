# %% [markdown]
# # Notes
#
# This assignment is partially autograded. Problems 2 and 3 are graded manually according to the following rules:
#
# - **1 point**: attempt was made, but solution is not correct,
# - **2 points**: solution is generally correct, but is not efficient/has unreasonably low performance,
# - **3 points**: solution is correct, is efficient/has reasonably high performance.
#
# Problem 1 is auto-graded.

# %%
# %pylab inline
plt.style.use("bmh")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.rcParams["figure.figsize"] = (6,6)

# %%
import numpy as np
import torch
from sklearn import datasets

# %%
STUDENT = "Matan Avitan"
ASSIGNMENT = 3
TEST = False

# %%
if TEST:
    import solutions
    total_grade = 0
    MAX_POINTS = 6

# %% [markdown]
# # Gradients

# %% [markdown]
# ### 1. Generate gradient (1 point).
#
# For 2-dimensional tensor `tr`, calculate a gradient of $\sum\log tr_{ij}$. Note, that you're provided with dimensions and interval:
#
# - `dims` is a tuple, so that `tr.size()` equals `dims`,
# - `lims` is an interval, so that `tr` elements are integeres, uniformly sampled from `[lims[0], lims[1])` interval (note, that lims[1] is **not** included).
#
# Result must be a tensor of the same shape as `tr`, containing gradients of the following function:
#
# $$\sum_{ij}\log tr_{ij}.$$
#
# Result **will be tested against multiple random combinations of input tensor dimensions ($10 \leq n < 100 $) and sampling interval (`lims[0]=1`, `10 <= lims[1] < 100`)**.

# %%
def generate_grad(dims, lims):
    """Generate gradient of `log(x)`."""
    tr = (lims[1] - lims[0]) * torch.rand(size=dims, requires_grad=True) + lims[0]
    print(tr)
    sum_log_tr = tr.log().sum()
    sum_log_tr.backward()
    return(tr.retain_grad)
generate_grad((1,10), [1,3])
# Out:
# tensor([[1.6568, 2.2350, 2.6118, 2.2299, 1.2189, 2.6289, 2.7755, 1.6455, 1.9594,
#          1.1540]], grad_fn=<AddBackward0>)
# <bound method Tensor.retain_grad of tensor([[1.6568, 2.2350, 2.6118, 2.2299, 1.2189, 2.6289, 2.7755, 1.6455, 1.9594,
#          1.1540]], grad_fn=<AddBackward0>)>

# %%
PROBLEM_ID = 1

if TEST:
    total_grade += solutions.check(STUDENT, PROBLEM_ID, generate_grad)

# %% [markdown]
# ### 2. Find a minimum (2 points, manually graded).
#
# Consider the following scalar function:
#
# $$
# f(x) = ax^2 + bx + c
# $$
#
# Given the $a,b,c$, find $x$, which minimizes $f'(x)$. Note this:
#
# - $a,b,c$ are fixed, and generated in such a way, that minimum always exists ($f(x)$ is convex),
# - $x$ is a scalar value, i.e. 0-dimensional tensor.

# %%
def generate_coeffs():
    a = torch.rand(size=()) * 10
    b = -10 + torch.rand(size=()) * 10
    c = -10 + torch.rand(size=()) * 10
    return a, b, c

def func(x, a, b, c):
    return x.pow(2) * a + x * b + c

# %%
EPOCHS = 20
LR = 1e-1
STARTING_VAL = 5. # Consider choosing different starting values for x to speed-up the optimization

# Initialize x, a, b, c
x = torch.tensor(data=STARTING_VAL, requires_grad=True)
a, b, c = generate_coeffs()

# Collect f(x) values during training for visuzalition later on
f_vals = []
print(x,a,b,c)
for i in range(EPOCHS):
    f_val = func(x, a, b, c)
    f_val.backward()
    print(f'n={i}',f'grad={x.grad}', f'x={x}', func(x, a, b, c))
    with torch.no_grad():
      x.sub_(LR * x.grad)
    x.grad.zero_()
    f_vals.append(f_val)
# Out:
# tensor(5., requires_grad=True) tensor(6.1787) tensor(-3.0963) tensor(-5.3835)
# n=0 grad=58.691184997558594 x=5.0 tensor(133.6037, grad_fn=<AddBackward0>)
# n=1 grad=-13.836413383483887 x=-0.8691186904907227 tensor(1.9747, grad_fn=<AddBackward0>)
# n=2 grad=3.26192569732666 x=0.5145226716995239 tensor(-5.3409, grad_fn=<AddBackward0>)
# n=3 grad=-0.7689971923828125 x=0.18833008408546448 tensor(-5.7475, grad_fn=<AddBackward0>)
# n=4 grad=0.181290864944458 x=0.26522982120513916 tensor(-5.7701, grad_fn=<AddBackward0>)
# n=5 grad=-0.042739152908325195 x=0.24710074067115784 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=6 grad=0.010075807571411133 x=0.25137466192245483 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=7 grad=-0.002375364303588867 x=0.25036707520484924 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=8 grad=0.0005598068237304688 x=0.2506045997142792 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=9 grad=-0.00013184547424316406 x=0.2505486309528351 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=10 grad=3.0994415283203125e-05 x=0.25056180357933044 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=11 grad=-7.3909759521484375e-06 x=0.2505587041378021 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=12 grad=1.9073486328125e-06 x=0.2505594491958618 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=13 grad=-2.384185791015625e-07 x=0.2505592703819275 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=14 grad=0.0 x=0.2505593001842499 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=15 grad=0.0 x=0.2505593001842499 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=16 grad=0.0 x=0.2505593001842499 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=17 grad=0.0 x=0.2505593001842499 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=18 grad=0.0 x=0.2505593001842499 tensor(-5.7714, grad_fn=<AddBackward0>)
# n=19 grad=0.0 x=0.2505593001842499 tensor(-5.7714, grad_fn=<AddBackward0>)

# %%
if f_vals:
    grid = np.linspace(-5, 5, 100)
    plt.plot(grid, np.square(grid) * a.item() + grid * b.item() + c.item())
    plt.hlines(f_vals[-1], -5, 5, "firebrick", "--", linewidth=1)

# %%
PROBLEM_ID = 2
GRADE = 0

if TEST:
    total_grade += GRADE

# %% [markdown]
# ### 3. Simple neural network model (3 points, manually graded).
#
# Construct non-linear model for binary classification. Use logistic regressions example from class as a blueprint. Experiment with different number of intermediate layers and their sizes to achieve good performance.
#
# For a reference, imagine a neural network with a single hidden layer with $N$ neurons. Then, input $X$ is first transformed as:
#
# $$
# X^{hidden}_{ik} = \sigma(X_{ij}W^{hidden}_{jk} + b^{hidden}_k),
# $$
# $$
# \hat y_{i} = \sigma(X^{hidden}_{ij}W_{j} + b).
# $$
#
# After this, $X^{hidden}_{ik}$ can be considered as an input to the same logistic regression model we had in class. The bonus is that we performed non-linear transformation of pur original coordinates and can now catch non-linear decision boundary (as is the case for our mock data).
#
# Note also, that $X$ has shape $(N, 2)$ (where $N$ is number of training examples), $W^{hidden}_{jk}$ has shape of $(2, N^{hidden})$ and $b^{hidden}_k$ has shape $(N^{hidden})$. At the same time, $W$ has shape $(N^{hidden},)$ and $b$ is a scalar (the same way it was for logistic regression). This model can be considered as a logistic regression on transformed coordinates, but we learn the transformation itself.
#
# There may be multiple hidden layers, but start from a single one.

# %%
N_LAYERS = 5
N_HIDDEN = (100,150,150,100,1)

# %%
X, y = datasets.make_moons(1000, noise=.25)

# %%
Xt = torch.tensor(X, dtype=torch.float)
yt = torch.tensor(np.expand_dims(y, axis=-1), dtype=torch.float)

# %%
weights = []
biases = []

for i in range(N_LAYERS):
    # Initialize w and b for layer i with number of "neurons" of N_HIDDEN[i]
    if i == 0:
        w =  torch.randn(2, N_HIDDEN[i], requires_grad=True)
        b =  torch.randn(1, N_HIDDEN[i], requires_grad=True)
    else:
        w =  torch.randn(N_HIDDEN[i-1], N_HIDDEN[i], requires_grad=True)
        b =  torch.randn(1, N_HIDDEN[i], requires_grad=True)
    weights.append(w)
    biases.append(b)

# %%
def sigmoid(a):
    """Sigmoid activation function."""

    return 1/(1 + (-a).exp())

def output(X, weights, biases):
    """Calculate neural network output."""
    return sigmoid(torch.mm(X, weights) + biases)

def logloss(y, y_pred):
    return -(y * torch.log(y_pred) + (1 - y) * torch.log(1 - y_pred)).mean()

# %%
EPOCHS = 1000
LR = 1e-1
DELTA = 0.00001
loss_history = []
y_pred_list=[]
for i in range(EPOCHS):
    for layer_level in range(N_LAYERS):
        if layer_level == 0:
            y_pred_list.append(output(Xt, weights[layer_level], biases[layer_level]))
        else:
            y_pred_list.append(output(y_pred, weights[layer_level], biases[layer_level]))
        y_pred = y_pred_list[-1]
    loss = logloss(yt, y_pred)
    loss.backward()
    
    loss_history.append(loss.item())

    with torch.no_grad():
        # update all the weights and biases
        # your code goes here
        for layer_level in range(N_LAYERS):
            weights[layer_level].sub_(LR * weights[layer_level].grad)
            biases[layer_level].sub_(LR * biases[layer_level].grad)

        # wipe out all gradients
        # your code goes here
    for layer_level in range(N_LAYERS):
        weights[layer_level].grad.zero_()
        biases[layer_level].grad.zero_()
            
    y_pred_list = []
        
    if i % 20 == 0:
        print(f"Epoch {i}: loss = {loss_history[-1]}")
        
    try:
        if loss_history[-2] - loss_history[-1] < DELTA:
            print(loss_history[-2] - loss_history[-1])
    except:
        pass
# Out:
# Epoch 0: loss = 0.8460007905960083
# Epoch 20: loss = 0.25090616941452026
# Epoch 40: loss = 0.19992268085479736
# Epoch 60: loss = 0.178624227643013
# Epoch 80: loss = 0.16861478984355927
# Epoch 100: loss = 0.16230635344982147
# Epoch 120: loss = 0.1579759120941162
# Epoch 140: loss = 0.15486326813697815
# Epoch 160: loss = 0.15253639221191406
# Epoch 180: loss = 0.15073691308498383
# Epoch 200: loss = 0.14930564165115356
# Epoch 220: loss = 0.14814049005508423
# Epoch 240: loss = 0.14717338979244232
# Epoch 260: loss = 0.14635679125785828
# Epoch 280: loss = 0.14565707743167877
# Epoch 300: loss = 0.1450493186712265
# Epoch 320: loss = 0.1445150226354599
# Epoch 340: loss = 0.14404034614562988
# Epoch 360: loss = 0.14361467957496643
# Epoch 380: loss = 0.14322981238365173
# Epoch 400: loss = 0.1428794413805008
# Epoch 420: loss = 0.14255863428115845
# Epoch 440: loss = 0.14226341247558594
# Epoch 460: loss = 0.14199067652225494
# Epoch 480: loss = 0.14173771440982819
# Epoch 500: loss = 0.14150238037109375
# Epoch 520: loss = 0.1412828266620636
# 9.998679161071777e-06
# Epoch 540: loss = 0.1410774439573288
# 9.968876838684082e-06
# 9.894371032714844e-06
# 9.879469871520996e-06
# 9.879469871520996e-06
# 9.834766387939453e-06
# 9.804964065551758e-06
# 9.745359420776367e-06
# 9.73045825958252e-06
# 9.715557098388672e-06
# 9.655952453613281e-06
# 9.685754776000977e-06
# 9.59634780883789e-06
# 9.581446647644043e-06
# 9.551644325256348e-06
# 9.492039680480957e-06
# 9.551644325256348e-06
# 9.417533874511719e-06
# 9.447336196899414e-06
# 9.402632713317871e-06
# 4.276633262634277e-06
# 4.276633262634277e-06
# 4.231929779052734e-06
# 4.26173210144043e-06
# 4.187226295471191e-06
# 4.246830940246582e-06
# 4.231929779052734e-06
# 4.172325134277344e-06
# 4.187226295471191e-06
# 4.246830940246582e-06
# 4.187226295471191e-06
# 4.157423973083496e-06
# 4.202127456665039e-06
# 4.157423973083496e-06
# Epoch 920: loss = 0.13868334889411926
# 4.1425228118896484e-06
# 4.202127456665039e-06
# 4.157423973083496e-06
# 4.157423973083496e-06
# 4.0978193283081055e-06
# 4.127621650695801e-06
# 4.1425228118896484e-06
# 4.127621650695801e-06
# 4.06801700592041e-06
# 4.127621650695801e-06
# 4.0978193283081055e-06
# 4.112720489501953e-06
# 4.082918167114258e-06
# 4.0531158447265625e-06
# 4.06801700592041e-06
# 4.06801700592041e-06
# 4.0978193283081055e-06
# 3.993511199951172e-06
# 4.112720489501953e-06
# 4.038214683532715e-06
# Epoch 940: loss = 0.1386014074087143
# 4.0084123611450195e-06
# 4.0531158447265625e-06
# 4.0084123611450195e-06
# 4.038214683532715e-06
# 4.0084123611450195e-06
# 4.0084123611450195e-06
# 3.978610038757324e-06
# 4.038214683532715e-06
# 3.948807716369629e-06
# 4.038214683532715e-06
# 3.919005393981934e-06
# 4.0084123611450195e-06
# 3.919005393981934e-06
# 3.978610038757324e-06
# 3.948807716369629e-06
# 3.978610038757324e-06
# 3.948807716369629e-06
# 3.948807716369629e-06
# 3.889203071594238e-06
# 3.919005393981934e-06
# Epoch 960: loss = 0.13852187991142273
# 3.948807716369629e-06
# 3.904104232788086e-06
# 3.889203071594238e-06
# 3.874301910400391e-06
# 3.933906555175781e-06
# 3.933906555175781e-06
# 3.844499588012695e-06
# 3.904104232788086e-06
# 3.844499588012695e-06
# 3.889203071594238e-06
# 3.874301910400391e-06
# 3.7997961044311523e-06
# 3.859400749206543e-06
# 3.889203071594238e-06
# 3.814697265625e-06
# 3.844499588012695e-06
# 3.829598426818848e-06
# 3.7848949432373047e-06
# 3.814697265625e-06
# 3.829598426818848e-06
# Epoch 980: loss = 0.1384446918964386
# 3.829598426818848e-06
# 3.7997961044311523e-06
# 3.7401914596557617e-06
# 3.844499588012695e-06
# 3.7848949432373047e-06
# 3.7997961044311523e-06
# 3.7550926208496094e-06
# 3.7848949432373047e-06
# 3.7848949432373047e-06
# 3.725290298461914e-06
# 3.769993782043457e-06
# 3.725290298461914e-06
# 3.7550926208496094e-06
# 3.7103891372680664e-06
# 3.814697265625e-06
# 3.6954879760742188e-06
# 3.680586814880371e-06
# 3.7848949432373047e-06
# 3.725290298461914e-06
# 3.680586814880371e-06

# %%
plt.figure(figsize=(14,6))
print(y_pred.shape)
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y_pred.detach().numpy().flatten(), alpha=0.6, edgecolor='k',
            cmap=plt.cm.coolwarm, vmin=0, vmax=1)
plt.colorbar()
plt.xlabel('$x_0$', fontsize=14)
plt.ylabel('$x_1$', fontsize=14)
plt.title("Predicted targets", fontsize=12)

plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.6, edgecolor='k',
            cmap=plt.cm.coolwarm, vmin=0, vmax=1)
plt.colorbar()
plt.xlabel('$x_0$', fontsize=14)
plt.ylabel('$x_1$', fontsize=14)
plt.title("Actual targets", fontsize=12)
plt.tight_layout()
# Out:
# torch.Size([1000, 1])

# %%
PROBLEM_ID = 3
GRADE = 0

if TEST:
    total_grade += GRADE

# %%
if TEST:
    print(f"{STUDENT}: {int(100 * total_grade / MAX_POINTS)}")
