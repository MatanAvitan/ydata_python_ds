# %% [markdown]
# # Notes
#
# This assignment is partially autograded. Problems 2 and 3 are graded manually according to the following rules:
#
# - **1 point**: attempt was made, but solution is not correct,
# - **2 points**: solution is generally correct, but is not efficient/has unreasonably low performance,
# - **3 points**: solution is correct, is efficient/has reasonably high performance.
#
# Problem 1 is auto-graded.

# %%
# %pylab inline
plt.style.use("bmh")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.rcParams["figure.figsize"] = (6,6)

# %%
import numpy as np
import torch
from sklearn import datasets

# %%
STUDENT = "Tomer Koren"
ASSIGNMENT = 3
TEST = False

# %%
if TEST:
    import solutions
    total_grade = 0
    MAX_POINTS = 6

# %% [markdown]
# # Gradients

# %% [markdown]
# ### 1. Generate gradient (1 point).
#
# For 2-dimensional tensor `tr`, calculate a gradient of $\sum\log tr_{ij}$. Note, that you're provided with dimensions and interval:
#
# - `dims` is a tuple, so that `tr.size()` equals `dims`,
# - `lims` is an interval, so that `tr` elements are integeres, uniformly sampled from `[lims[0], lims[1])` interval (note, that lims[1] is **not** included).
#
# Result must be a tensor of the same shape as `tr`, containing gradients of the following function:
#
# $$\sum_{ij}\log tr_{ij}.$$
#
# Result **will be tested against multiple random combinations of input tensor dimensions ($10 \leq n < 100 $) and sampling interval (`lims[0]=1`, `10 <= lims[1] < 100`)**.

# %%
def generate_grad(dims, lims):
    tr = torch.zeros(*dims).random_(*lims)
    tr.requires_grad = True    
    tr_sum = tr.log().sum()    
    tr_sum.backward()    
    return tr.grad

# %%
if not TEST:
    n_rows = 3
    n_cols = 4
    lims = [1,12]
    tr = torch.zeros(n_rows, n_cols).random_(*lims)
    print('tr random values:\n',tr)
    dims = tr.size()    
    grads = generate_grad(dims,lims)
    print('grad values:\n',grads)
# Out:
# tr random values:
#  tensor([[ 5.,  1.,  4.,  2.],
#         [ 6., 11.,  9.,  8.],
#         [ 5., 11.,  3.,  8.]])
# grad values:
#  tensor([[0.3333, 0.5000, 0.5000, 0.5000],
#         [0.3333, 0.1667, 0.5000, 1.0000],
#         [0.1250, 0.1000, 0.1429, 0.0909]])

# %%
PROBLEM_ID = 1

if TEST:
    total_grade += solutions.check(STUDENT, PROBLEM_ID, generate_grad)

# %% [markdown]
# ### 2. Find a minimum (2 points, manually graded).
#
# Consider the following scalar function:
#
# $$
# f(x) = ax^2 + bx + c
# $$
#
# Given the $a,b,c$, find $x$, which minimizes $f'(x)$. Note this:
#
# - $a,b,c$ are fixed, and generated in such a way, that minimum always exists ($f(x)$ is convex),
# - $x$ is a scalar value, i.e. 0-dimensional tensor.

# %%
def generate_coeffs():
    a = torch.rand(size=()) * 10
    b = -10 + torch.rand(size=()) * 10
    c = -10 + torch.rand(size=()) * 10
    return a, b, c

def func(x, a, b, c):
    return x.pow(2) * a + x * b + c

# %%
EPOCHS = 20
LR = 1e-1
STARTING_VAL = 1. # Consider choosing different starting values for x to speed-up the optimization
                  # RENARK : We have performed several tests to estimate the average theoretical min value of x.
                  #          We saw that if we use this value (~1) as a starting val, 
                  #          the number of ecpochs is the lowest in avg ~11. 
                  #          calculation are performed in the Unit test block below
DELTA = 0.0001 # threshold for stopping the training cycle when there is no more improvment in the optimisation goal.

# Initialize x, a, b, c
x = torch.tensor(data=STARTING_VAL, requires_grad = True) 
a, b, c = generate_coeffs()

# Collect f(x) values during training for visuzalition later on
f_vals = []

for i in range(EPOCHS):
    # Your code goes here    
    f = func(x,a,b,c)
    f.backward()
    
    f_vals.append(f.item())
    
    with torch.no_grad():
        x.sub_(LR * x.grad)
        
    x.grad.zero_()
    
    try:
        if f_vals[-2] - f_vals[-1] < DELTA:
            break
    except:
        pass
            
if not TEST:
    print('num of optimisation steps: ',len(f_vals))
    print('theoretical x value : ',(-b/(2*a)).item())    
    print('theoretical f(x) min value: ',func(-b/(2*a),a,b,c).item())
    print('optimisation x value : ',x.item())
    print('optimisation f(x) min value: ',f_vals[-1])
# Out:
# num of optimisation steps:  6
# theoretical x value :  0.46927955746650696
# theoretical f(x) min value:  -10.275869369506836
# optimisation x value :  0.4693300426006317
# optimisation f(x) min value:  -10.275869369506836

# %%
if not TEST:
    FIND_INIT_VAL_X = True
    FIND_AVG_EPOCH_VAL_X = True
    
    # This method helps to define the starting value of x on this problem                      
    def estimate_average_x(num_samples = 1000):
        # Collect f(x) values during training for visuzalition later on
        x_theoretical_samples = []

        for i in range(num_samples):        
            a, b, c = generate_coeffs()
            x_theoretical_samples.append((-b/(2*a)).item())
    
        x_theoretical_samples = np.array(x_theoretical_samples)
        print('percentile :',np.percentile(x_theoretical_samples, [90, 95,98, 99,100]))
        perc_99th = np.percentile(x_theoretical_samples, 98)    
        x_theoretical_samples_filtered = x_theoretical_samples[x_theoretical_samples < perc_99th]
        print('mean: ',np.mean(x_theoretical_samples_filtered))
        print('std: ',np.std(x_theoretical_samples_filtered))
        plt.hist(x_theoretical_samples_filtered,bins=30,density=True)
        plt.xlabel("x theoretical ")
        plt.ylabel("density")
        return np.mean(x_theoretical_samples_filtered)
        
    # this method perform optimisation and return the number of steps for convergence for delta of 0.0001
    def run_optimisation(STARTING_VAL=30,EPOCHS = 20):
        LR = 1e-1        
        DELTA = 0.0001 # threshold for stopping the training cycle when there is no more improvment in the optimisation goal.

        # Initialize x, a, b, c
        x = torch.zeros(size=())+ STARTING_VAL
        x.requires_grad = True
        a, b, c = generate_coeffs()

        # Collect f(x) values during training for visuzalition later on
        f_vals = []

        for i in range(EPOCHS):
            # Your code goes here    
            f = func(x,a,b,c)
            f.backward()

            f_vals.append(f.item())

            with torch.no_grad():
                x.sub_(LR * x.grad)

            x.grad.zero_()

            try:
                if f_vals[-2] - f_vals[-1] < DELTA:
                    break
            except:
                pass
        
        return len(f_vals)
        
    def estimate_average_epochs_per_x(x_range = [1,50], num_samples = 1000):
        x_start_vals = np.arange(*x_range)
        avg_n_per_x = np.zeros(x_range)        
        max_epoch = 20
        
        for x_start_val in x_start_vals:            
            n_samples = []
            for i in np.arange(num_samples):                
                n = run_optimisation(x_start_val,max_epoch)
                n_samples.append(n)
            
            avg_n_per_x[:,x_start_val-1] = np.mean(n_samples)
            
        return avg_n_per_x
                    
    if FIND_INIT_VAL_X:
        avg_x = estimate_average_x()
    if FIND_AVG_EPOCH_VAL_X:
        num_epocs_per_x = estimate_average_epochs_per_x()
        print(num_epocs_per_x)
# Out:
# percentile : [  2.71994483   5.592908    14.41633726  27.89789337 423.57345581]
# mean:  1.03108737913821
# std:  1.7516609122207334
# [[11.137 11.604 12.345 12.596 12.752 12.798 13.03  13.205 13.058 13.781
#   13.412 13.79  13.403 13.545 13.674 13.998 13.743 14.003 13.837 14.107
#   13.94  13.83  14.189 14.223 14.318 13.938 14.353 14.341 14.207 14.022
#   14.364 14.449 14.214 14.305 13.997 14.261 14.472 14.264 14.552 14.252
#   14.233 14.257 14.24  14.68  14.674 14.734 14.601 14.501 14.281  0.   ]]

# %%
if f_vals:
    grid = np.linspace(-5, 5, 100)
    plt.plot(grid, np.square(grid) * a.item() + grid * b.item() + c.item())
    plt.hlines(f_vals[-1], -5, 5, "firebrick", "--", linewidth=1)

# %%
PROBLEM_ID = 2
GRADE = 0

if TEST:
    total_grade += GRADE

# %% [markdown]
# ### 3. Simple neural network model (3 points, manually graded).
#
# Construct non-linear model for binary classification. Use logistic regressions example from class as a blueprint. Experiment with different number of intermediate layers and their sizes to achieve good performance.
#
# For a reference, imagine a neural network with a single hidden layer with $N$ neurons. Then, input $X$ is first transformed as:
#
# $$
# X^{hidden}_{ik} = \sigma(X_{ij}W^{hidden}_{jk} + b^{hidden}_k),
# $$
# $$
# \hat y_{i} = \sigma(X^{hidden}_{ij}W_{j} + b).
# $$
#
# After this, $X^{hidden}_{ik}$ can be considered as an input to the same logistic regression model we had in class. The bonus is that we performed non-linear transformation of pur original coordinates and can now catch non-linear decision boundary (as is the case for our mock data).
#
# Note also, that $X$ has shape $(N, 2)$ (where $N$ is number of training examples), $W^{hidden}_{jk}$ has shape of $(2, N^{hidden})$ and $b^{hidden}_k$ has shape $(N^{hidden})$. At the same time, $W$ has shape $(N^{hidden},)$ and $b$ is a scalar (the same way it was for logistic regression). This model can be considered as a logistic regression on transformed coordinates, but we learn the transformation itself.
#
# There may be multiple hidden layers, but start from a single one.

# %%
N_LAYERS = 3 # assumed as to the number of hidden layers in the network (i.e 0 == no hidden layers, single neuron on the netowkr)
N_HIDDEN = (150,200,100)

# %%
X, y = datasets.make_moons(1000, noise=.25)

# %%
Xt = torch.tensor(X, dtype=torch.float)
yt = torch.tensor(np.expand_dims(y, axis=-1), dtype=torch.float)

# %%
weights = []
biases = []

for i in range(N_LAYERS):
    # Initialize w and b for layer i with number of "neurons" of N_HIDDEN[i]
    
    in_layer_size = Xt.size()[1] if i == 0 else N_HIDDEN[i-1]
    out_layer_size = 1 if i+1 == N_LAYERS else N_HIDDEN[i]
    
    w = torch.randn(in_layer_size,out_layer_size, requires_grad=True)  # <- your code goes here                
    b = torch.randn(out_layer_size, requires_grad=True) # <- your code goes here        
    weights.append(w)
    biases.append(b)

# %%
def sigmoid(a):
    """Sigmoid activation function."""

    return 1/(1 + (-a).exp())

def output(X, weights, biases):
    """Calculate neural network output.""" 
    layer_output = []
    for i in range(N_LAYERS):
        if i == 0:
            layer_output.append(sigmoid(torch.mm(X, weights[i]) + biases[i]))
        else:
            layer_output.append(sigmoid(torch.mm(layer_output[i-1], weights[i]) + biases[i]))
    return layer_output[-1]

def logloss(y, y_pred):        
    return -(y * torch.log(y_pred) + (1 - y) * torch.log(1 - y_pred)).mean()

# %%
EPOCHS = 1000
LR = 1e-1
DELTA = 0.00001
loss_history = []

for i in range(EPOCHS):
    y_pred = output(Xt, weights, biases)
    loss = logloss(yt, y_pred)
    loss.backward()
    
    loss_history.append(loss.item())

    with torch.no_grad():
        # update all the weights and biases
        # your code goes here
        for layer_idx in range(N_LAYERS):
            weights[layer_idx].sub_(LR * weights[layer_idx].grad)
            biases[layer_idx].sub_(LR * biases[layer_idx].grad)

    # wipe out all gradients
    # your code goes here
    for layer_idx in range(N_LAYERS):
        weights[layer_idx].grad.zero_()
        biases[layer_idx].grad.zero_()    
        
    if i % 20 == 0:
        print(f"Epoch {i}: loss = {loss_history[-1]}")
    
    try:
        if loss_history[-2] - loss_history[-1] < DELTA:
            break
    except:
        pass
# Out:
# Epoch 0: loss = 5.664378643035889
# Epoch 20: loss = 0.2245476096868515
# Epoch 40: loss = 0.19630129635334015
# Epoch 60: loss = 0.1842087358236313
# Epoch 80: loss = 0.17663653194904327
# Epoch 100: loss = 0.17131663858890533
# Epoch 120: loss = 0.1673274040222168
# Epoch 140: loss = 0.1641983985900879
# Epoch 160: loss = 0.1616620272397995
# Epoch 180: loss = 0.15955403447151184
# Epoch 200: loss = 0.1577676236629486
# Epoch 220: loss = 0.156230166554451
# Epoch 240: loss = 0.15489019453525543
# Epoch 260: loss = 0.15370996296405792
# Epoch 280: loss = 0.15266135334968567
# Epoch 300: loss = 0.1517227292060852
# Epoch 320: loss = 0.15087704360485077
# Epoch 340: loss = 0.15011098980903625
# Epoch 360: loss = 0.14941352605819702
# Epoch 380: loss = 0.14877577126026154
# Epoch 400: loss = 0.1481904536485672
# Epoch 420: loss = 0.14765140414237976
# Epoch 440: loss = 0.14715328812599182
# Epoch 460: loss = 0.14669175446033478
# Epoch 480: loss = 0.14626307785511017
# Epoch 500: loss = 0.145863875746727
# Epoch 520: loss = 0.1454913169145584
# Epoch 540: loss = 0.14514300227165222
# Epoch 560: loss = 0.14481669664382935
# Epoch 580: loss = 0.1445104479789734
# Epoch 600: loss = 0.14422255754470825
# Epoch 620: loss = 0.14395156502723694
# Epoch 640: loss = 0.14369602501392365
# Epoch 660: loss = 0.1434548795223236
# Epoch 680: loss = 0.14322681725025177
# Epoch 700: loss = 0.14301101863384247

# %%
if not TEST:
    plt.subplot(2, 1, 1)    
    plt.plot(loss_history)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    loss = loss_history[-1]
    print('Final Loss: ',loss, '\nProb Estimation: ', np.exp(-loss))
    y_ = y_pred.detach().numpy().flatten()
    from sklearn.metrics import classification_report
    y_class = (y_ >= 0.5).astype(np.int)
    print(classification_report(y,y_class))
    plt.subplot(2, 1, 2)
    plt.hist(y_[y==0],range=(0,1))
    plt.xlabel("probability")
    plt.ylabel("count")
    plt.hist(y_[y==1],range=(0,1))
# Out:
# Final Loss:  0.14282649755477905
# Prob Estimation:  0.8669044658925936
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       500
#            1       0.94      0.96      0.95       500
#
#     accuracy                           0.95      1000
#    macro avg       0.95      0.95      0.95      1000
# weighted avg       0.95      0.95      0.95      1000

# %%
plt.figure(figsize=(14,6))

plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y_pred.detach().numpy().flatten(), alpha=0.6, edgecolor='k',
            cmap=plt.cm.coolwarm, vmin=0, vmax=1)
plt.colorbar()
plt.xlabel('$x_0$', fontsize=14)
plt.ylabel('$x_1$', fontsize=14)
plt.title("Predicted targets", fontsize=12)

plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.6, edgecolor='k',
            cmap=plt.cm.coolwarm, vmin=0, vmax=1)
plt.colorbar()
plt.xlabel('$x_0$', fontsize=14)
plt.ylabel('$x_1$', fontsize=14)
plt.title("Actual targets", fontsize=12)
plt.tight_layout()

# %%
PROBLEM_ID = 3
GRADE = 0

if TEST:
    total_grade += GRADE

# %%
if TEST:
    print(f"{STUDENT}: {int(100 * total_grade / MAX_POINTS)}")
